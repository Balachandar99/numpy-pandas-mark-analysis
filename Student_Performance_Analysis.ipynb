# %% [markdown]
# **Import Libraries**

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# **Student IDs**

# %%
student_id = np.arange(1,101)

# %%
student_name = []
for i in range (1,101):
  student_name.append(f"student_name_{i}")
print(student_name[:5])
# Out:
# ['student_name_1', 'student_name_2', 'student_name_3', 'student_name_4', 'student_name_5']

# %% [markdown]
# **Student Marks**

# %%
maths_marks=np.random.randint(35,100,100)
english_marks = np.random.randint(35,100,100)
science_mark = np.random.randint(35,100,100)

# %%
attendence = np.random.randint(85,100,100)

# %%
print(attendence[:20])
# Out:
# [88 87 88 95 89 86 87 89 97 93 86 91 97 94 98 96 99 93 90 85]

# %%
gender = np.random.choice(['Male','Female'],100)

# %%
student_dept = np.random.choice(['b.com','it','EEE','CSE','Tech'],100)
print(student_dept[:15])
# Out:
# ['CSE' 'EEE' 'b.com' 'CSE' 'EEE' 'CSE' 'Tech' 'b.com' 'CSE' 'CSE' 'CSE'
#  'Tech' 'Tech' 'EEE' 'EEE']

# %%
df=pd.DataFrame({'Student_Id': student_id, 'Name': student_name,'Gender': gender,'Dept':student_dept,'Maths': maths_marks,'English':english_marks,'Science':science_mark, 'Attendennce':attendence,De})

# %%
df
# Out:
#     Student_Id              Name  Gender   Dept  Maths  English  Science  \
# 0            1    student_name_1    Male    CSE     72       48       36
# 1            2    student_name_2  Female    EEE     73       39       63
# 2            3    student_name_3    Male  b.com     68       38       41
# 3            4    student_name_4  Female    CSE     80       44       85
# 4            5    student_name_5  Female    EEE     82       68       90
# ..         ...               ...     ...    ...    ...      ...      ...
# 95          96   student_name_96    Male   Tech     47       39       77
# 96          97   student_name_97  Female   Tech     73       62       74
# 97          98   student_name_98  Female  b.com     58       86       75
# 98          99   student_name_99    Male     it     61       62       52
# 99         100  student_name_100  Female   Tech     59       79       86
#
#     Attendennce
# 0            88
# 1            87
# 2            88
# 3            95
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student_Id   100 non-null    int64
#  1   Name         100 non-null    object
#  2   Gender       100 non-null    object
#  3   Dept         100 non-null    object
#  4   Maths        100 non-null    int64
#  5   English      100 non-null    int64
#  6   Science      100 non-null    int64
#  7   Attendennce  100 non-null    int64
# dtypes: int64(5), object(3)
# memory usage: 6.4+ KB

# %%
df.describe()
# Out:
#        Student_Id       Maths     English     Science  Attendennce
# count  100.000000  100.000000  100.000000  100.000000   100.000000
# mean    50.500000   68.870000   66.900000   66.180000    90.950000
# std     29.011492   17.161535   18.486413   18.391028     4.495508
# min      1.000000   35.000000   36.000000   35.000000    85.000000
# 25%     25.750000   55.000000   50.000000   51.750000    87.000000
# 50%     50.500000   68.000000   68.000000   66.500000    89.000000
# 75%     75.250000   84.250000   84.500000   82.250000    95.000000
# max    100.000000   99.000000   95.000000   99.000000    99.000000

# %%
df['total']= (df['Maths']+df['English']+df['Science'])

# %%
df
# Out:
#     Student_Id              Name  Gender   Dept  Maths  English  Science  \
# 0            1    student_name_1    Male    CSE     72       48       36
# 1            2    student_name_2  Female    EEE     73       39       63
# 2            3    student_name_3    Male  b.com     68       38       41
# 3            4    student_name_4  Female    CSE     80       44       85
# 4            5    student_name_5  Female    EEE     82       68       90
# ..         ...               ...     ...    ...    ...      ...      ...
# 95          96   student_name_96    Male   Tech     47       39       77
# 96          97   student_name_97  Female   Tech     73       62       74
# 97          98   student_name_98  Female  b.com     58       86       75
# 98          99   student_name_99    Male     it     61       62       52
# 99         100  student_name_100  Female   Tech     59       79       86
#
#     Attendennce  total
# 0            88    156
# 1            87    175
# ...

# %%
df['Average']= df['total']/3

# %%
df
# Out:
#     Student_Id              Name  Gender   Dept  Maths  English  Science  \
# 0            1    student_name_1    Male    CSE     72       48       36
# 1            2    student_name_2  Female    EEE     73       39       63
# 2            3    student_name_3    Male  b.com     68       38       41
# 3            4    student_name_4  Female    CSE     80       44       85
# 4            5    student_name_5  Female    EEE     82       68       90
# ..         ...               ...     ...    ...    ...      ...      ...
# 95          96   student_name_96    Male   Tech     47       39       77
# 96          97   student_name_97  Female   Tech     73       62       74
# 97          98   student_name_98  Female  b.com     58       86       75
# 98          99   student_name_99    Male     it     61       62       52
# 99         100  student_name_100  Female   Tech     59       79       86
#
#     Attendennce  total    Average
# 0            88    156  52.000000
# ...

# %%
df['Grade']= np.where ( df['Average']>=90 ,'A',np.where (df['Average']>=75,'B', np.where (df['Average']>=50,'C','Fail')))

# %%
df
# Out:
#     Student_Id              Name  Gender   Dept  Maths  English  Science  \
# 0            1    student_name_1    Male    CSE     72       48       36
# 1            2    student_name_2  Female    EEE     73       39       63
# 2            3    student_name_3    Male  b.com     68       38       41
# 3            4    student_name_4  Female    CSE     80       44       85
# 4            5    student_name_5  Female    EEE     82       68       90
# ..         ...               ...     ...    ...    ...      ...      ...
# 95          96   student_name_96    Male   Tech     47       39       77
# 96          97   student_name_97  Female   Tech     73       62       74
# 97          98   student_name_98  Female  b.com     58       86       75
# 98          99   student_name_99    Male     it     61       62       52
# 99         100  student_name_100  Female   Tech     59       79       86
#
#     Attendennce  total    Average Grade
# 0            88    156  52.000000     C
# ...

# %%
Row_total = df[['English','Maths','Science']].sum(axis=1)
column_average = df[['English','Maths','Science']].mean(axis=0)

# %%
column_average
# Out:
# English    66.90
# Maths      68.87
# Science    66.18
# dtype: float64

# %%
np.mean(df['Average'])
np.median(df['Average'])
# Out:
# np.float64(67.5)

# %%
np.max(df['Average'])
np.min(df['Average'])
# Out:
# 39.666666666666664

# %%
top_student= df.sort_values(by='total',ascending=False)
top_student.head(10)
# Out:
#     Student_Id             Name  Gender   Dept  Maths  English  Science  \
# 66          67  student_name_67    Male    CSE     93       86       95
# 25          26  student_name_26    Male    EEE     91       94       84
# 43          44  student_name_44    Male    EEE     99       78       92
# 10          11  student_name_11  Female    CSE     77       95       96
# 34          35  student_name_35    Male    CSE     72       90       99
# 77          78  student_name_78    Male    EEE     86       76       99
# 27          28  student_name_28  Female    CSE     82       86       87
# 9           10  student_name_10  Female    CSE     87       70       97
# 31          32  student_name_32    Male  b.com     73       87       88
# 73          74  student_name_74  Female   Tech     85       83       78
#
#     Attendennce  total    Average Grade
# 66           93    274  91.333333     A
# 25           87    269  89.666667     B
# 43           85    269  89.666667     B
# ...

# %%
top_student
# Out:
#     Student_Id             Name  Gender   Dept  Maths  English  Science  \
# 66          67  student_name_67    Male    CSE     93       86       95
# 25          26  student_name_26    Male    EEE     91       94       84
# 43          44  student_name_44    Male    EEE     99       78       92
# 10          11  student_name_11  Female    CSE     77       95       96
# 34          35  student_name_35    Male    CSE     72       90       99
# ..         ...              ...     ...    ...    ...      ...      ...
# 2            3   student_name_3    Male  b.com     68       38       41
# 71          72  student_name_72    Male    CSE     55       50       42
# 70          71  student_name_71  Female     it     39       60       44
# 58          59  student_name_59  Female    EEE     49       40       52
# 26          27  student_name_27  Female    CSE     36       39       44
#
#     Attendennce  total    Average Grade
# 66           93    274  91.333333     A
# ...

# %%
Stident_above_Avg = df[df['Average']>80]

# %%
Stident_above_Avg
# Out:
#     Student_Id             Name  Gender   Dept  Maths  English  Science  \
# 5            6   student_name_6  Female    CSE     72       74       97
# 9           10  student_name_10  Female    CSE     87       70       97
# 10          11  student_name_11  Female    CSE     77       95       96
# 23          24  student_name_24    Male   Tech     59       84       98
# 25          26  student_name_26    Male    EEE     91       94       84
# 27          28  student_name_28  Female    CSE     82       86       87
# 28          29  student_name_29  Female    CSE     89       67       85
# 31          32  student_name_32    Male  b.com     73       87       88
# 34          35  student_name_35    Male    CSE     72       90       99
# 43          44  student_name_44    Male    EEE     99       78       92
# 66          67  student_name_67    Male    CSE     93       86       95
# 73          74  student_name_74  Female   Tech     85       83       78
# ...

# %%
Dept_Avg = df.groupby('Dept')['Average'].mean()
Dept_Avg
# Out:
# Dept
# CSE      70.027778
# EEE      69.507246
# Tech     64.777778
# b.com    65.562500
# it       65.187500
# Name: Average, dtype: float64

# %%
Gender_Average = df.groupby('Gender')['Average'].mean()
Gender_Average
# Out:
# Gender
# Female    67.713450
# Male      66.790698
# Name: Average, dtype: float64

# %%
df
# Out:
#     Student_Id              Name  Gender   Dept  Maths  English  Science  \
# 0            1    student_name_1    Male    CSE     72       48       36
# 1            2    student_name_2  Female    EEE     73       39       63
# 2            3    student_name_3    Male  b.com     68       38       41
# 3            4    student_name_4  Female    CSE     80       44       85
# 4            5    student_name_5  Female    EEE     82       68       90
# ..         ...               ...     ...    ...    ...      ...      ...
# 95          96   student_name_96    Male   Tech     47       39       77
# 96          97   student_name_97  Female   Tech     73       62       74
# 97          98   student_name_98  Female  b.com     58       86       75
# 98          99   student_name_99    Male     it     61       62       52
# 99         100  student_name_100  Female   Tech     59       79       86
#
#     Attendennce  total    Average Grade
# 0            88    156  52.000000     C
# ...

# %%
df
# Out:
#     Student_Id              Name  Gender   Dept  Maths  English  Science  \
# 0            1    student_name_1    Male    CSE     72       48       36
# 1            2    student_name_2  Female    EEE     73       39       63
# 2            3    student_name_3    Male  b.com     68       38       41
# 3            4    student_name_4  Female    CSE     80       44       85
# 4            5    student_name_5  Female    EEE     82       68       90
# ..         ...               ...     ...    ...    ...      ...      ...
# 95          96   student_name_96    Male   Tech     47       39       77
# 96          97   student_name_97  Female   Tech     73       62       74
# 97          98   student_name_98  Female  b.com     58       86       75
# 98          99   student_name_99    Male     it     61       62       52
# 99         100  student_name_100  Female   Tech     59       79       86
#
#     Attendennce  total    Average Grade
# 0            88    156  52.000000     C
# ...

# %%
df['Name'] = df['Name'].replace('student_name_2', np.nan)
df['Maths'] = df['Maths'].replace(79, np.nan)
df['Maths'] = df['Maths'].replace(91, np.nan)
df['English'] = df['English'].replace(84, np.nan)
df['English'] = df['English'].replace(90, np.nan)
df['Science'] = df['Science'].replace(52, np.nan)
df['Science'] = df['Science'].replace(62, np.nan)

# %%
df
# Out:
#     Student_Id              Name  Gender   Dept  Maths  English  Science  \
# 0            1    student_name_1    Male    CSE   72.0     48.0     36.0
# 1            2               NaN  Female    EEE   73.0     39.0     63.0
# 2            3    student_name_3    Male  b.com   68.0     38.0     41.0
# 3            4    student_name_4  Female    CSE   80.0     44.0     85.0
# 4            5    student_name_5  Female    EEE   82.0     68.0     90.0
# ..         ...               ...     ...    ...    ...      ...      ...
# 95          96   student_name_96    Male   Tech   47.0     39.0     77.0
# 96          97   student_name_97  Female   Tech   73.0     62.0     74.0
# 97          98   student_name_98  Female  b.com   58.0     86.0     75.0
# 98          99   student_name_99    Male     it   61.0     62.0      NaN
# 99         100  student_name_100  Female   Tech   59.0     79.0     86.0
#
#     Attendennce  total    Average Grade
# 0            88    156  52.000000     C
# ...

# %%
df.isnull().sum()
# Out:
# Student_Id     0
# Name           1
# Gender         0
# Dept           0
# Maths          3
# English        4
# Science        5
# Attendennce    0
# total          0
# Average        0
# Grade          0
# dtype: int64

# %%
df['Maths']=df['Maths'].fillna(df['Maths'].mean())


# df['Math'] = df['Math'].fillna(df['Math'].mean())

# %%
mean_maths= df['Maths'].mean()
mean_maths
# Out:
# np.float64(68.30927835051546)

# %%
df['Maths']=df['Maths'].fillna(mean_maths)

# %%
mean_english= df['English'].mean()
df['English']= df['English'].fillna(mean_english)

# %%
mean_science= df['Science'].mean()
df['Science']=df['Science'].fillna(mean_science)

# %%
df.isnull().sum()
# Out:
# Student_Id     0
# Name           1
# Gender         0
# Dept           0
# Maths          0
# English        0
# Science        0
# Attendennce    0
# total          0
# Average        0
# Grade          0
# dtype: int64

# %%
df['Name']=df['Name'].fillna('student_name_2')

# %%
df
# Out:
#     Student_Id              Name  Gender   Dept  Maths  English    Science  \
# 0            1    student_name_1    Male    CSE   72.0     48.0  36.000000
# 1            2    student_name_2  Female    EEE   73.0     39.0  63.000000
# 2            3    student_name_3    Male  b.com   68.0     38.0  41.000000
# 3            4    student_name_4  Female    CSE   80.0     44.0  85.000000
# 4            5    student_name_5  Female    EEE   82.0     68.0  90.000000
# ..         ...               ...     ...    ...    ...      ...        ...
# 95          96   student_name_96    Male   Tech   47.0     39.0  77.000000
# 96          97   student_name_97  Female   Tech   73.0     62.0  74.000000
# 97          98   student_name_98  Female  b.com   58.0     86.0  75.000000
# 98          99   student_name_99    Male     it   61.0     62.0  66.821053
# 99         100  student_name_100  Female   Tech   59.0     79.0  86.000000
#
#     Attendennce  total    Average Grade
# ...

# %%
df.isnull().sum()
# Out:
# Student_Id     0
# Name           0
# Gender         0
# Dept           0
# Maths          0
# English        0
# Science        0
# Attendennce    0
# total          0
# Average        0
# Grade          0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Student_Id, Name, Gender, Dept, Maths, English, Science, Attendennce, total, Average, Grade]
# Index: []

# %%
df.to_csv('Student_Performance_Analysis.csv',index=False)

# %%
print('Total_Student:', len(df))
print('Highest Total:',np.max(df['total']))
print('Lowest Total:',np.min(df['total']))
print('Average_Total:',np.average(df['total']))
# Out:
# Total_Student: 100
# Highest Total: 274
# Lowest Total: 119
# Average_Total: 201.95
